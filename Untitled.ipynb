# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('icc_wc_23_bowl.csv')
print(df)
# Out:
#                   player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  \
# 0     Dilshan Madushanka   10.0        0    80        5      8.00  25   8   2
# 1    Dushmantha Chameera   10.0        2    71        1      7.10  28   8   2
# 2          Kasun Rajitha    9.0        0    65        0      7.22  25   7   2
# 3         Angelo Mathews    3.0        0    11        0      3.66  10   1   0
# 4     Maheesh Theekshana   10.0        0    67        0      6.70  18   5   1
# ..                   ...    ...      ...   ...      ...       ...  ..  ..  ..
# 569         David Willey   10.0        0    56        3      5.60  37   8   1
# 570         Chris Woakes    5.3        0    27        1      4.90  22   5   0
# 571          Adil Rashid   10.0        0    55        2      5.50  26   4   1
# 572         Gus Atkinson    8.0        0    45        2      5.62  29   3   3
# 573            Moeen Ali   10.0        0    60        2      6.00  27   7   1
#
# ...

# %%
df
# Out:
#                   player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  \
# 0     Dilshan Madushanka   10.0        0    80        5      8.00  25   8   2
# 1    Dushmantha Chameera   10.0        2    71        1      7.10  28   8   2
# 2          Kasun Rajitha    9.0        0    65        0      7.22  25   7   2
# 3         Angelo Mathews    3.0        0    11        0      3.66  10   1   0
# 4     Maheesh Theekshana   10.0        0    67        0      6.70  18   5   1
# ..                   ...    ...      ...   ...      ...       ...  ..  ..  ..
# 569         David Willey   10.0        0    56        3      5.60  37   8   1
# 570         Chris Woakes    5.3        0    27        1      4.90  22   5   0
# 571          Adil Rashid   10.0        0    55        2      5.50  26   4   1
# 572         Gus Atkinson    8.0        0    45        2      5.62  29   3   3
# 573            Moeen Ali   10.0        0    60        2      6.00  27   7   1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   player    574 non-null    object
#  1   overs     574 non-null    float64
#  2   maidens   574 non-null    int64
#  3   runs      574 non-null    int64
#  4   wickets   574 non-null    int64
#  5   run_rate  574 non-null    float64
#  6   0s        574 non-null    int64
#  7   4s        574 non-null    int64
#  8   6s        574 non-null    int64
#  9   wd        574 non-null    int64
#  10  nb        574 non-null    int64
#  11  team      574 non-null    object
#  12  opponent  574 non-null    object
#  13  innings   574 non-null    int64
#  14  match_id  574 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 67.4+ KB

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['player', 'overs', 'maidens', 'runs', 'wickets', 'run_rate', '0s', '4s',
#        '6s', 'wd', 'nb', 'team', 'opponent', 'innings', 'match_id'],
#       dtype='object')

# %%
column_mapping = {'wd': 'Wides', 'nb': 'No_balls'}
df.rename(columns=column_mapping, inplace=True)

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['player', 'overs', 'maidens', 'runs', 'wickets', 'run_rate', '0s', '4s',
#        '6s', 'Wides', 'No_balls', 'team', 'opponent', 'innings', 'match_id'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   player    574 non-null    object
#  1   overs     574 non-null    float64
#  2   maidens   574 non-null    int64
#  3   runs      574 non-null    int64
#  4   wickets   574 non-null    int64
#  5   run_rate  574 non-null    float64
#  6   0s        574 non-null    int64
#  7   4s        574 non-null    int64
#  8   6s        574 non-null    int64
#  9   Wides     574 non-null    int64
#  10  No_balls  574 non-null    int64
#  11  team      574 non-null    object
#  12  opponent  574 non-null    object
#  13  innings   574 non-null    int64
#  14  match_id  574 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 67.4+ KB

# %%
df.head(10)
# Out:
#                 player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  \
# 0   Dilshan Madushanka   10.0        0    80        5      8.00  25   8   2
# 1  Dushmantha Chameera   10.0        2    71        1      7.10  28   8   2
# 2        Kasun Rajitha    9.0        0    65        0      7.22  25   7   2
# 3       Angelo Mathews    3.0        0    11        0      3.66  10   1   0
# 4   Maheesh Theekshana   10.0        0    67        0      6.70  18   5   1
# 5      Dushan Hemantha    8.0        0    52        0      6.50  17   2   2
# 6           Aryan Dutt   10.0        0    48        1      4.80  37   7   0
# 7       Logan van Beek    6.0        0    30        1      5.00  20   4   0
# 8      Colin Ackermann    8.0        1    39        2      4.87  26   1   2
# 9    Paul van Meekeren    6.0        0    40        1      6.66  16   5   0
#
#    Wides  No_balls         team  opponent  innings  match_id
# 0      6         0    Sri Lanka     India        1         0
# ...

# %%
df.tail(10)
# Out:
#                 player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  \
# 564     Logan van Beek    9.0        1    30        1      3.33  39   3   0
# 565    Colin Ackermann    7.0        1    25        1      3.57  29   2   1
# 566  Paul van Meekeren    7.2        0    23        4      3.13  30   2   0
# 567       Bas de Leede    7.0        0    25        2      3.57  30   4   0
# 568       Shariz Ahmad    2.0        0    13        0      6.50   5   2   0
# 569       David Willey   10.0        0    56        3      5.60  37   8   1
# 570       Chris Woakes    5.3        0    27        1      4.90  22   5   0
# 571        Adil Rashid   10.0        0    55        2      5.50  26   4   1
# 572       Gus Atkinson    8.0        0    45        2      5.62  29   3   3
# 573          Moeen Ali   10.0        0    60        2      6.00  27   7   1
#
#      Wides  No_balls         team    opponent  innings  match_id
# 564      4         0  Netherlands  Bangladesh        2        46
# ...

# %%
 df.isnull().sum()
# Out:
# player      0
# overs       0
# maidens     0
# runs        0
# wickets     0
# run_rate    0
# 0s          0
# 4s          0
# 6s          0
# Wides       0
# No_balls    0
# team        0
# opponent    0
# innings     0
# match_id    0
# dtype: int64

# %%
df.describe()
# Out:
#             overs     maidens        runs     wickets    run_rate          0s  \
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     7.351045    0.256098   42.322300    1.202091    5.922369   22.918118
# std      2.685601    0.533933   19.651473    1.193757    2.135935   10.251561
# min      0.300000    0.000000    1.000000    0.000000    1.350000    0.000000
# 25%      6.000000    0.000000   30.000000    0.000000    4.500000   16.000000
# 50%      8.000000    0.000000   41.000000    1.000000    5.660000   24.000000
# 75%     10.000000    0.000000   55.000000    2.000000    7.075000   30.000000
# max     10.000000    3.000000  115.000000    7.000000   16.000000   48.000000
#
#                4s          6s       Wides    No_balls     innings    match_id
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     3.900697    1.121951    1.158537    0.097561    1.480836   23.691638
# ...

# %%
df.rename(columns=lambda x: x.capitalize(), inplace=True)

# %%
df.describe()
# Out:
#             Overs     Maidens        Runs     Wickets    Run_rate          0s  \
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     7.351045    0.256098   42.322300    1.202091    5.922369   22.918118
# std      2.685601    0.533933   19.651473    1.193757    2.135935   10.251561
# min      0.300000    0.000000    1.000000    0.000000    1.350000    0.000000
# 25%      6.000000    0.000000   30.000000    0.000000    4.500000   16.000000
# 50%      8.000000    0.000000   41.000000    1.000000    5.660000   24.000000
# 75%     10.000000    0.000000   55.000000    2.000000    7.075000   30.000000
# max     10.000000    3.000000  115.000000    7.000000   16.000000   48.000000
#
#                4s          6s       Wides    No_balls     Innings    Match_id
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     3.900697    1.121951    1.158537    0.097561    1.480836   23.691638
# ...

# %%
total_runs_by_country = df.groupby('Team')['Runs'].sum()
sorted_countries = total_runs_by_country.sort_values(ascending=False)
print(sorted_countries)
# Out:
# Team
# Australia       2749
# New Zealand     2664
# Pakistan        2566
# Netherlands     2527
# Sri Lanka       2424
# Bangladesh      2414
# South Africa    2324
# England         2261
# India           2220
# Afghanistan     2144
# Name: Runs, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sorted_countries.plot(kind='bar', color='skyblue')
plt.title('Total Runs by Country in ICC World Cups')
plt.xlabel('Country')
plt.ylabel('Total Runs')
plt.xticks(rotation=45)
plt.show()

# %%
# Group by 'Player' and calculate the total runs for each player
total_runs_by_player = df.groupby('Player')['Runs'].sum()

# Sort the players based on total runs in descending order
sorted_players = total_runs_by_player.sort_values(ascending=False)

# Select the top 5 players
top_5_players = sorted_players.head(5)
print(sorted_players)
# Out:
# Player
# Haris Rauf               533
# Mitchell Starc           528
# Dilshan Madushanka       525
# Adam Zampa               515
# Pat Cummins              515
#                         ...
# Cameron Green             11
# Shubman Gill              11
# Charith Asalanka          10
# Rohit Sharma               7
# Najmul Hossain Shanto      5
# Name: Runs, Length: 102, dtype: int64

# %%
# Group by 'Team', 'Player', and calculate the total runs for each player in each team
total_runs_by_player_team = df.groupby(['Team', 'Player'])['Runs'].sum()

# Sort the players based on total runs in descending order
sorted_players = total_runs_by_player_team.sort_values(ascending=False)

# Select the top 5 players
top_5_players = sorted_players.head(5)

# Display the top 5 players with the highest total runs including team names
print(top_5_players)
# Out:
# Team       Player
# Pakistan   Haris Rauf            533
# Australia  Mitchell Starc        528
# Sri Lanka  Dilshan Madushanka    525
# Australia  Pat Cummins           515
#            Adam Zampa            515
# Name: Runs, dtype: int64

# %%
# Group by 'Team', 'Player', and calculate the total runs for each player in each team
total_runs_by_player_team = df.groupby(['Team', 'Player'])['Runs'].sum()

# Sort the players based on total runs in descending order
sorted_players = total_runs_by_player_team.sort_values(ascending=False)

# Select the top 5 players
top_5_players = sorted_players.head(5)

# Define different colors for each bar
colors = ['skyblue', 'lightgreen', 'lightcoral', 'lightsalmon', 'lightblue']

# Plot a bar chart for the top 5 players with different colors and rotated labels
plt.figure(figsize=(10, 6))
bars = top_5_players.plot(kind='bar', color=colors)
plt.title('Top 5 Players with Highest Total Runs in Each Team')
plt.xlabel('Team, Player')
plt.ylabel('Total Runs')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')

# Annotate each bar with its value
for i, v in enumerate(top_5_players):
    plt.text(i, v + 5, str(v), ha='center', va='bottom', color='black')

plt.show()

# %%
# Group by 'Team', 'Player', and calculate the total number of 6s for each player in each team
total_6s_by_player_team = df.groupby(['Team', 'Player'])['6s'].sum()

# Sort the players based on total 6s in descending order
sorted_players_6s = total_6s_by_player_team.sort_values(ascending=False)

# Select the top 5 players with the highest number of 6s
top_5_players_6s = sorted_players_6s.head(5)

# Plot a bar chart for the top 5 players with different colors and rotated labels
plt.figure(figsize=(10, 6))
bars = top_5_players_6s.plot(kind='bar', color='lightgreen')
plt.title('Top 5 Players with Highest Number of 6s in Each Team')
plt.xlabel('Team, Player')
plt.ylabel('Total 6s')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')

# Annotate each bar with its value
for i, v in enumerate(top_5_players_6s):
    plt.text(i, v + 1, str(v), ha='center', va='bottom', color='black')

plt.show()

# %%
# Group by 'Team', 'Player', and calculate the total number of 4s for each player in each team
total_4s_by_player_team = df.groupby(['Team', 'Player'])['4s'].sum()

# Sort the players based on total 4s in descending order
sorted_players_4s = total_4s_by_player_team.sort_values(ascending=False)

# Select the top 5 players with the highest number of 4s
top_5_players_4s = sorted_players_4s.head(5)

# Plot a bar chart for the top 5 players with different colors and rotated labels
plt.figure(figsize=(10, 6))
bars = top_5_players_4s.plot(kind='bar', color='lightcoral')
plt.title('Top 5 Players with Highest Number of 4s in Each Team')
plt.xlabel('Team, Player')
plt.ylabel('Total 4s')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')

# Annotate each bar with its value
for i, v in enumerate(top_5_players_4s):
    plt.text(i, v + 1, str(v), ha='center', va='bottom', color='black')

plt.show()

# %%
print(df.columns)
# Out:
# Index(['Player', 'Overs', 'Maidens', 'Runs', 'Wickets', 'Run_rate', '0s', '4s',
#        '6s', 'Wides', 'No_balls', 'Team', 'Opponent', 'Innings', 'Match_id'],
#       dtype='object')

# %%
# Sort the DataFrame by 'Wickets' in descending order
sorted_players_by_wickets = df.sort_values(by='Wickets', ascending=False)

# Select the top 5 players
top_5_players = sorted_players_by_wickets.head(5)

# Display the top 5 players with their country and wicket count
print("Top 5 Players with the Highest Number of Wickets:")
print(top_5_players[['Player', 'Team', 'Wickets']])
# Out:
# Top 5 Players with the Highest Number of Wickets:
#                   Player         Team  Wickets
# 347       Mohammed Shami        India        7
# 0     Dilshan Madushanka    Sri Lanka        5
# 446     Mitchell Santner  New Zealand        5
# 78        Mohammed Shami        India        5
# 233  Shaheen Shah Afridi     Pakistan        5

# %%
player_names = top_5_players['Player']
wickets_counts = top_5_players['Wickets']
countries = top_5_players['Team']  # Replace with the actual column name containing country information

# Plotting the bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(player_names + ' (' + countries + ')', wickets_counts, color='lightcoral')
plt.title('Top 5 Players with Highest Number of Wickets')
plt.xlabel('Player (Country)')
plt.ylabel('Number of Wickets')

# Annotate each bar with its value
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', color='black')

# Show the plot
plt.show()

# %%
# Sort the DataFrame by 'Runs' in ascending order to get the top 10 players
top_10_players = df.sort_values(by='Runs', ascending=True).head(10)

# Bar chart for the top 10 players
plt.figure(figsize=(12, 8))
bars = plt.barh(top_10_players['Player'], top_10_players['Overs'], color='skyblue', label='Overs')
bars = plt.barh(top_10_players['Player'], top_10_players['Runs'], color='orange', label='Runs')

# Annotate each bar with its value
for bar, overs, runs, team in zip(bars, top_10_players['Overs'], top_10_players['Runs'], top_10_players['Team']):
    plt.text(bar.get_x() + bar.get_width(), bar.get_y() + bar.get_height() / 2,
             f'{overs} Overs, {runs} Runs\nTeam: {team}',
             ha='left', va='center', color='black')

plt.title('Top 10 Players - Overs and Runs (Bottom to Top)')
plt.xlabel('Count')
plt.ylabel('Player')
plt.legend()

plt.show()

# %%
# Sort the DataFrame by 'Runs' given by each bowler in descending order to get the top 10 bowlers
top_10_bowlers = df.sort_values(by='Runs', ascending=False).head(10)

# Create a subplot with a specified size
fig, ax = plt.subplots(figsize=(12, 5))

# Bar chart for the top 10 bowlers
bars = ax.barh(top_10_bowlers['Player'], top_10_bowlers['Runs'], color='red', label='Runs Given')

# Annotate each bar with its value
for bar, runs in zip(bars, top_10_bowlers['Runs']):
    ax.text(bar.get_x() + bar.get_width(), bar.get_y() + bar.get_height() / 2,
            f'{runs} Runs Given',
            ha='left', va='center', color='black')

ax.set_title('Top 10 Bowlers - Runs Given (High to Low)', fontsize=16)
ax.set_xlabel('Runs Given', fontsize=12)
ax.set_ylabel('Bowler', fontsize=12)
ax.legend()

plt.show()

# %%
# Select the top 30 players based on 'Overs'
df_player_overs_top_30 = df.sort_values(by='Overs', ascending=False).head(30)

fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot bars for 'Overs' on the primary y-axis (ax1)
index = np.arange(len(df_player_overs_top_30))
bars = ax1.bar(index, df_player_overs_top_30['Overs'], label='Overs', color='skyblue')

# Plot line for 'Maidens' on the same y-axis (ax1)
line = ax1.plot(index, df_player_overs_top_30['Maidens'], color='orange', marker='o', label='Maidens')

# Set labels and titles
ax1.set_xlabel('Player')
ax1.set_ylabel('Overs', color='skyblue')
ax1.tick_params(axis='y', labelcolor='skyblue')  # Make sure y-axis labels are in blue

plt.title('Maiden Overs and Overs for the Top 30 Players')

# Combine legends
bars_legend = [bar for bar in bars]
line_legend = [line[0]]
plt.legend(bars_legend + line_legend, ['Overs', 'Maidens'], loc='upper left')

# Set x-axis ticks and labels
plt.xticks(index, df_player_overs_top_30['Player'], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
wickets_by_team = df.groupby('Team')['Wickets'].sum().reset_index()

# Plot a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(wickets_by_team['Team'], wickets_by_team['Wickets'], color='lightcoral')
plt.title('Wickets Taken by Each Team')
plt.xlabel('Team')
plt.ylabel('Total Wickets')
plt.xticks(rotation=45, ha='right')

# Annotate each bar with its value
for bar, value in zip(bars, wickets_by_team['Wickets']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, str(value),
             ha='center', va='bottom', color='black')

plt.show()

# %%
maiden_overs_by_team = df.groupby('Team')['Maidens'].sum().reset_index()

# Plot a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(maiden_overs_by_team['Team'], maiden_overs_by_team['Maidens'], color='skyblue')
plt.title('Maiden Overs by Each Team')
plt.xlabel('Team')
plt.ylabel('Total Maiden Overs')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')

# Annotate each bar with its value
for bar, value in zip(bars, maiden_overs_by_team['Maidens']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, str(value),
             ha='center', va='bottom', color='black')

plt.show()

# %%
run_rate_by_team = df.groupby('Team')['Run_rate'].mean().reset_index()

# Plot a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(run_rate_by_team['Team'], run_rate_by_team['Run_rate'], color='lightgreen')
plt.title('Average Run Rate by Each Team (Bowlers)')
plt.xlabel('Team')
plt.ylabel('Average Run Rate')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')
# Annotate each bar with its value
for bar, value in zip(bars, run_rate_by_team['Run_rate']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, f'{value:.2f}',
             ha='center', va='bottom', color='black')

plt.show()

# %%
total_wickets = df['Wickets'].sum()
print("Total Wickets:", total_wickets)
# Out:
# Total Wickets: 690

# %%
total_wickets_by_team = df.groupby('Team')['Wickets'].sum()
print("Total Wickets by Team:")
print(total_wickets_by_team)
# Out:
# Total Wickets by Team:
# Team
# Afghanistan     53
# Australia       86
# Bangladesh      51
# England         65
# India           99
# Netherlands     62
# New Zealand     71
# Pakistan        65
# South Africa    88
# Sri Lanka       50
# Name: Wickets, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(total_wickets_by_team, labels=total_wickets_by_team.index, autopct='%1.1f%%', startangle=90)
plt.title('Total Wickets by Each Team')
plt.show()

# %%
# Sort the DataFrame by 'Wickets' in descending order
sorted_players_by_wickets = df.sort_values(by='Wickets', ascending=False)

# Select the top 5 players
top_5_players = sorted_players_by_wickets.head(5)

# Display the top 5 players with their names and wicket counts
print("Top 5 Players with the Highest Number of Wickets:")
print(top_5_players[['Player', 'Wickets']])
# Out:
# Top 5 Players with the Highest Number of Wickets:
#                   Player  Wickets
# 347       Mohammed Shami        7
# 0     Dilshan Madushanka        5
# 446     Mitchell Santner        5
# 78        Mohammed Shami        5
# 233  Shaheen Shah Afridi        5

# %%
# Sort the DataFrame by 'Wickets' in descending order
sorted_players_by_wickets = df.sort_values(by='Wickets', ascending=False)

# Select the top 5 players
top_5_players = sorted_players_by_wickets.head(5)

# Display the top 5 players with their names, wicket counts, and teams without index numbers
print("Top 5 Players with the Highest Number of Wickets:")
print(top_5_players[['Player', 'Wickets', 'Team']].to_string(index=False))
# Out:
# Top 5 Players with the Highest Number of Wickets:
#              Player  Wickets        Team
#      Mohammed Shami        7       India
#  Dilshan Madushanka        5   Sri Lanka
#    Mitchell Santner        5 New Zealand
#      Mohammed Shami        5       India
# Shaheen Shah Afridi        5    Pakistan
